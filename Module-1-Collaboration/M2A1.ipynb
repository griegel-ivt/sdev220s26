# %% [markdown]
# 4.1

# %%
secret = 5

# %%
guess = 8

# %%
if (guess < secret):
    print("too low")
elif (guess > secret):
    print("too high")
else:
    print("just right")
# Out:
# too high

# %% [markdown]
# 4.2

# %%
small = True

# %%
green = False

# %%
if (small and green):
    print("pea")
elif (small and not green):
    print("cherry")
elif (not small and green):
    print("watermelon")
else:
    print("pumpkin")
# Out:
# cherry

# %% [markdown]
# 6.1

# %%
for nummy in [3, 2, 1, 0]:
    print(nummy)
# Out:
# 3
# 2
# 1
# 0

# %% [markdown]
# 6.2

# %%
guess_me = 7

# %%
number = 1

# %%
while True:
    if (number < guess_me):
        print("too low")
    elif (number > guess_me):
        print("oops")
        break
    else:
        print("found it!")
        break
    number += 1
# Out:
# too low
# too low
# too low
# too low
# too low
# too low
# found it!

# %% [markdown]
# 6.3

# %%
guess_me = 5

# %%
for number in range(10):
    if (number < guess_me):
        print("too low")
    elif (number == guess_me):
        print("found it!")
        break
    else:
        print("oops")
        break
# Out:
# too low
# too low
# too low
# too low
# too low
# found it!
